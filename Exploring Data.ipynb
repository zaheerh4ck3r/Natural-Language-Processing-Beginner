# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import webtext
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to /home/zaheer/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# True

# %%
import pandas as pd
wt_sentences = webtext.sents('firefox.txt')
wt_words = webtext.words('firefox.txt')
df = pd.DataFrame(wt_sentences)
df
# Out:
#               0          1       2            3          4          5    \
# 0          Cookie    Manager       :            "        Don          '
# 1               [        XUL       ]    Implement      Cocoa          -
# 2               #     ifdefs     for  MOZ_PHOENIX  customize     dialog
# 3     Customising    toolbar  breaks          the   throbber          !
# 4          manage  bookmarks  causes         hang       land        pch
# ...           ...        ...     ...          ...        ...        ...
# 1139         Show     Failed     URL       should         be       part
# 1140     dragging          a    link         over        the  Downloads
# 1141     Keyboard  shortcuts      on    bookmarks       menu   starting
# 1142      Address        bar      is        blank      after          '
# 1143          BMP        can   cause          all  available     memory
#
#              6        7              8      9    ...   653   654   655   656  \
# 0              t    allow          sites   that  ...  None  None  None  None
# 1          style  toolbar  customization      .  ...  None  None  None  None
# 2              '        s        toolbar    has  ...  None  None  None  None
# 3           None     None           None   None  ...  None  None  None  None
# 4              '        s      bookmarks  patch  ...  None  None  None  None
# ...          ...      ...            ...    ...  ...   ...   ...   ...   ...
# 1139          of  Firefox            The   Site  ...  None  None  None  None
# 1140          or       Go         button  doesn  ...  None  None  None  None
# 1141        with        B             or      M  ...  None  None  None  None
# 1142  connection  refused              '  after  ...  None  None  None  None
# 1143          to       be       consumed     by  ...  None  None  None  None
#
#        657   658   659   660   661   662
# 0     None  None  None  None  None  None
# 1     None  None  None  None  None  None
# 2     None  None  None  None  None  None
# 3     None  None  None  None  None  None
# 4     None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...
# 1139  None  None  None  None  None  None
# 1140  None  None  None  None  None  None
# 1141  None  None  None  None  None  None
# 1142  None  None  None  None  None  None
# 1143  None  None  None  None  None  None
#
# [1144 rows x 663 columns]

# %%
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string

# %%
frequency_dist = FreqDist(wt_words)
frequency_dist
# Out:
# FreqDist({'.': 2428, 'in': 2203, 'to': 2130, '"': 1971, 'the': 1762, "'": 1507, 'not': 1472, '-': 1372, 'when': 1255, 'on': 1193, ...})

# %%
sorted_frequency_dist =sorted(frequency_dist,key=frequency_dist.__getitem__,reverse=True)

# %%
sorted_frequency_dist
# Out:
# ['.',
#  'in',
#  'to',
#  '"',
#  'the',
#  "'",
#  'not',
#  '-',
#  'when',
#  'on',
#  'a',
#  'is',
#  't',
#  'and',
#  'of',
#  '(',
#  'page',
#  'for',
#  'with',
#  ')',
#  'window',
#  'Firefox',
#  'does',
#  'from',
#  'open',
#  ':',
#  'menu',
#  'should',
#  'bar',
#  'tab',
#  'doesn',
#  'after',
#  'Firebird',
#  'new',
#  'work',
#  'browser',
#  'if',
#  'be',
#  '0',
#  'toolbar',
#  'button',
#  'bookmarks',
#  'dialog',
#  'bookmark',
#  'as',
#  'file',
#  'URL',
#  'download',
#  'crashes',
#  'I',
#  'no',
#  'text',
#  'are',
#  'or',
#  'up',
#  'crash',
#  'click',
#  'tabs',
#  'Bookmarks',
#  'link',
#  '/',
#  'firefox',
#  'manager',
#  '+',
#  'using',
#  'it',
#  'Mozilla',
#  'default',
#  'error',
#  'all',
#  'an',
#  'clicking',
#  's',
#  'windows',
#  'search',
#  'folder',
#  ']',
#  'Phoenix',
#  '1',
#  'at',
#  'icon',
#  'Manager',
#  'by',
#  'this',
#  'site',
#  'can',
#  'files',
#  'Page',
#  'fails',
#  'causes',
#  'use',
#  'close',
#  '[',
#  'opening',
#  'Toolbar',
#  'Add',
#  'has',
#  'Bookmark',
#  'right',
#  'display',
#  'down',
#  'that',
#  'theme',
#  'box',
#  'Download',
#  '9',
#  'The',
#  'pages',
#  'firebird',
#  'only',
#  'url',
#  'while',
#  'have',
#  'image',
#  'links',
#  'When',
#  'location',
#  'Crash',
#  'option',
#  'scroll',
#  'load',
#  'cannot',
#  'Options',
#  'address',
#  '>',
#  'Can',
#  'start',
#  'password',
#  'com',
#  'do',
#  '->',
#  'extension',
#  'install',
#  'back',
#  'buttons',
#  'history',
#  'loading',
#  'don',
#  'you',
#  'web',
#  'form',
#  'instead',
#  'wrong',
#  'No',
#  'show',
#  'mouse',
#  'build',
#  'sidebar',
#  'about',
#  'focus',
#  'will',
#  'http',
#  '://',
#  'set',
#  'broken',
#  'Windows',
#  'popup',
#  'some',
#  'icons',
#  'opens',
#  'drop',
#  'context',
#  'into',
#  'autocomplete',
#  '8',
#  'preferences',
#  'missing',
#  'screen',
#  'one',
#  'save',
#  'Open',
#  'field',
#  'print',
#  'Ctrl',
#  'working',
#  'images',
#  'profile',
#  'other',
#  'options',
#  'mozilla',
#  'add',
#  'New',
#  'Find',
#  'Browser',
#  'startup',
#  'any',
#  'change',
#  'size',
#  'list',
#  'javascript',
#  'opened',
#  'first',
#  'type',
#  'user',
#  'too',
#  'trying',
#  'but',
#  '2',
#  'like',
#  '<',
#  'extensions',
#  'displayed',
#  'multiple',
#  'Save',
#  'phoenix',
#  'selected',
#  'Cannot',
#  'time',
#  'i',
#  'won',
#  'shows',
#  'properly',
#  'over',
#  'appears',
#  'view',
#  'Error',
#  'X',
#  'name',
#  'correctly',
#  'always',
#  ';',
#  'left',
#  'item',
#  'hangs',
#  'appear',
#  'background',
#  'menus',
#  'UI',
#  'directory',
#  'input',
#  'application',
#  'themes',
#  'version',
#  'message',
#  'same',
#  'blank',
#  'View',
#  'Web',
#  'www',
#  'File',
#  'middle',
#  'Tab',
#  'OS',
#  'even',
#  'go',
#  'folders',
#  'scrolling',
#  'html',
#  'keyboard',
#  'off',
#  'without',
#  'non',
#  'Tools',
#  'Menu',
#  'line',
#  'my',
#  'Preferences',
#  'proxy',
#  'saved',
#  'out',
#  '6',
#  'sites',
#  'IE',
#  'Clicking',
#  'select',
#  'content',
#  'Search',
#  'home',
#  'than',
#  'update',
#  'shortcut',
#  'items',
#  'get',
#  'under',
#  'source',
#  'preview',
#  'current',
#  'closing',
#  '&',
#  'find',
#  'Javascript',
#  'clicked',
#  'cookies',
#  '|',
#  'plugin',
#  'empty',
#  'key',
#  'History',
#  'remove',
#  'running',
#  '...',
#  'disabled',
#  'longer',
#  'support',
#  'dropdown',
#  'status',
#  'installer',
#  'installing',
#  '7',
#  'works',
#  'displays',
#  'document',
#  'allow',
#  'JavaScript',
#  'Password',
#  'shown',
#  'After',
#  'top',
#  'downloads',
#  'OK',
#  'last',
#  'mode',
#  'Folder',
#  'more',
#  'enter',
#  'drag',
#  'website',
#  'freezes',
#  'wheel',
#  'login',
#  'launch',
#  'another',
#  'needs',
#  'bug',
#  '3',
#  'About',
#  'ctrl',
#  'being',
#  'Unable',
#  'Print',
#  'function',
#  'Installer',
#  'Text',
#  'Help',
#  'used',
#  'disable',
#  'Extension',
#  'js',
#  'Use',
#  'problem',
#  'try',
#  'installed',
#  'downloading',
#  'XML',
#  'make',
#  'Need',
#  '%',
#  'settings',
#  'Linux',
#  'As',
#  'cursor',
#  'enabled',
#  'still',
#  'Java',
#  'run',
#  'closed',
#  'found',
#  '::',
#  'small',
#  'builds',
#  'main',
#  'chrome',
#  'Tabs',
#  'system',
#  'access',
#  'Mac',
#  '=',
#  'its',
#  'installation',
#  '[@',
#  'browsing',
#  'slow',
#  'Profile',
#  'breaks',
#  'Location',
#  '()',
#  'Bar',
#  'flash',
#  'Wrong',
#  'certain',
#  'Image',
#  'Default',
#  'changes',
#  'loaded',
#  'two',
#  'characters',
#  'pop',
#  'URLs',
#  'Link',
#  'selection',
#  'server',
#  'loads',
#  'between',
#  'information',
#  'CPU',
#  'switching',
#  'code',
#  'style',
#  'then',
#  'auto',
#  'import',
#  '4',
#  'Window',
#  'incorrectly',
#  'command',
#  'was',
#  'Not',
#  '..."',
#  'gets',
#  'webpage',
#  'complete',
#  'CSS',
#  'FireFox',
#  'customize',
#  'second',
#  '!',
#  'large',
#  'via',
#  'delete',
#  'Sidebar',
#  'exe',
#  'tag',
#  'me',
#  'Internet',
#  'Popup',
#  'java',
#  'changing',
#  'entry',
#  'different',
#  'way',
#  'Dialog',
#  'Flash',
#  'until',
#  'full',
#  'stop',
#  'pref',
#  'selecting',
#  'connection',
#  'problems',
#  'nothing',
#  'dll',
#  'there',
#  'already',
#  'remember',
#  'through',
#  'boxes',
#  'restart',
#  'incorrect',
#  '5',
#  'cache',
#  'homepage',
#  'Info',
#  'In',
#  'very',
#  'rendering',
#  'warning',
#  'which',
#  'cookie',
#  'stops',
#  'results',
#  'arrow',
#  'org',
#  'preference',
#  'character',
#  'Downloads',
#  'mail',
#  'title',
#  'data',
#  'XP',
#  'Form',
#  'available',
#  'Customize',
#  'Autocomplete',
#  'Remove',
#  'Make',
#  '?',
#  'clear',
#  'times',
#  'copy',
#  'Source',
#  'sometimes',
#  'google',
#  'request',
#  'HTML',
#  'makes',
#  'Theme',
#  'submit',
#  'fields',
#  'create',
#  'starting',
#  'This',
#  'before',
#  'them',
#  'Extensions',
#  'Opening',
#  'uses',
#  'prefs',
#  'visible',
#  'info',
#  'gives',
#  'alert',
#  'old',
#  'properties',
#  'keys',
#  'goes',
#  'lost',
#  '="',
#  'blocking',
#  'favicon',
#  'disappear',
#  'toolbars',
#  'doesnt',
#  'upon',
#  'viewing',
#  'automatically',
#  'need',
#  'hang',
#  'switch',
#  'showing',
#  'Back',
#  'each',
#  'external',
#  'Home',
#  'refresh',
#  'string',
#  'All',
#  'blocked',
#  '100',
#  'during',
#  'setting',
#  'unable',
#  'many',
#  'Right',
#  'Thunderbird',
#  'navigation',
#  'move',
#  'every',
#  'space',
#  'downloaded',
#  'contains',
#  'Middle',
#  'double',
#  'active',
#  'Option',
#  'disk',
#  'If',
#  'Address',
#  'scrollbar',
#  'expand',
#  'session',
#  'Images',
#  'Go',
#  'completely',
#  'personal',
#  'color',
#  'fonts',
#  'forms',
#  'updated',
#  'where',
#  'value',
#  'closes',
#  'prompt',
#  'monitor',
#  'within',
#  'desktop',
#  'nightly',
#  'render',
#  'linux',
#  'reload',
#  'Yahoo',
#  'release',
#  'deleted',
#  'end',
#  'passwords',
#  'app',
#  'inside',
#  'next',
#  'Context',
#  'forward',
#  'possible',
#  'part',
#  'added',
#  'textbox',
#  'feature',
#  'Show',
#  'just',
#  'Themes',
#  'Auto',
#  'Alt',
#  'Downloading',
#  'program',
#  'help',
#  'Enter',
#  'A',
#  'so',
#  'been',
#  'long',
#  'plugins',
#  'isn',
#  'choose',
#  'RFE',
#  'shortcuts',
#  'Toolbars',
#  'CTRL',
#  'itself',
#  'Update',
#  'usage',
#  'ability',
#  'Implement',
#  'order',
#  'ignored',
#  'area',
#  'twice',
#  'position',
#  'Preview',
#  'disappears',
#  'existing',
#  'Mouse',
#  'Click',
#  'behaviour',
#  'edit',
#  'e',
#  'cause',
#  'see',
#  'displaying',
#  'again',
#  'filename',
#  'deleting',
#  'https',
#  'local',
#  'cust',
#  'adding',
#  'remote',
#  'table',
#  'accessing',
#  'dragging',
#  'Ability',
#  'typing',
#  'network',
#  'action',
#  'Site',
#  'immediately',
#  'starts',
#  'created',
#  'certificate',
#  'saving',
#  'fail',
#  'font',
#  'handling',
#  'popups',
#  'Crashes',
#  'enable',
#  'due',
#  'css',
#  'cancel',
#  'able',
#  'hidden',
#  'panel',
#  'Close',
#  'specific',
#  'Set',
#  'HTTP',
#  'PDF',
#  'failed',
#  'email',
#  'Change',
#  'previous',
#  'could',
#  'stored',
#  'Start',
#  'net',
#  'Shift',
#  'send',
#  'rendered',
#  'User',
#  'checkbox',
#  'typed',
#  'Using',
#  'config',
#  'Cookie',
#  'checked',
#  'memory',
#  'above',
#  'resize',
#  'imported',
#  'number',
#  'failure',
#  'tooltip',
#  'now',
#  'contents',
#  'pdf',
#  'Full',
#  'Icon',
#  'functionality',
#  'Double',
#  'It',
#  're',
#  'username',
#  'entered',
#  'bad',
#  'href',
#  'event',
#  'visiting',
#  'autoscroll',
#  'changed',
#  'Don',
#  'removed',
#  'stay',
#  'script',
#  'attempting',
#  'tree',
#  'Privacy',
#  'x',
#  'effect',
#  'single',
#  'state',
#  'control',
#  'exception',
#  'fullscreen',
#  'creates',
#  'shift',
#  'responding',
#  'path',
#  'present',
#  'Google',
#  'dialogs',
#  'crashed',
#  'anymore',
#  'plug',
#  'locks',
#  'frame',
#  'console',
#  'zip',
#  '*',
#  'secure',
#  'seems',
#  'Personal',
#  'Scroll',
#  'respond',
#  'containing',
#  'launching',
#  'place',
#  'going',
#  'overflow',
#  'Get',
#  'black',
#  'Selecting',
#  'side',
#  'keyword',
#  'loses',
#  'behavior',
#  'accept',
#  'column',
#  '--',
#  'bars',
#  'shouldn',
#  'says',
#  'entries',
#  'printing',
#  'websites',
#  'On',
#  'header',
#  'never',
#  'Security',
#  'Screen',
#  'xul',
#  'jar',
#  'blocker',
#  'applet',
#  'bottom',
#  'width',
#  'paste',
#  'what',
#  'Cancel',
#  'Allow',
#  'anything',
#  'Display',
#  'Install',
#  'Manage',
#  'away',
#  'pressing',
#  'Menus',
#  'once',
#  'Request',
#  'ignores',
#  'specified',
#  'returns',
#  'exit',
#  'include',
#  'Build',
#  'tags',
#  'random',
#  'parsing',
#  '\\',
#  'tabbed',
#  'MozillaFirebird',
#  'attribute',
#  'stylesheet',
#  'DOM',
#  'Edit',
#  'Bad',
#  'authentication',
#  'Mail',
#  'cut',
#  'Icons',
#  'domain',
#  'Some',
#  'block',
#  'tools',
#  'Should',
#  'object',
#  'w',
#  'loop',
#  'takes',
#  'yahoo',
#  'Advanced',
#  'Font',
#  'Type',
#  'frames',
#  'Explorer',
#  'types',
#  'process',
#  'Desktop',
#  'correct',
#  'Enable',
#  'tries',
#  'take',
#  'Please',
#  'renders',
#  'sort',
#  'applications',
#  'With',
#  'Cookies',
#  'Plugin',
#  'favicons',
#  'Problem',
#  'Incorrect',
#  'Create',
#  'fine',
#  'check',
#  'pops',
#  'keeps',
#  'defined',
#  'freeze',
#  'several',
#  '")',
#  'needed',
#  'MS',
#  'XPI',
#  'Installing',
#  'root',
#  'port',
#  'elements',
#  'profiles',
#  'notification',
#  'entering',
#  'keywords',
#  'target',
#  'rdf',
#  'Inspector',
#  'called',
#  'made',
#  'customization',
#  'throbber',
#  'fix',
#  'Navigation',
#  'restore',
#  'standard',
#  'Keyboard',
#  'security',
#  'hide',
#  'invalid',
#  'look',
#  '10',
#  'defaults',
#  'scrollbars',
#  'big',
#  'looks',
#  'latest',
#  'engine',
#  '."',
#  '".',
#  'dual',
#  'undefined',
#  'gtk2',
#  'exist',
#  'listed',
#  '("',
#  'embedded',
#  'FB',
#  'Feature',
#  'given',
#  'collapse',
#  'though',
#  'Missing',
#  'Import',
#  'becomes',
#  'arrows',
#  'urlbar',
#  'os',
#  'Do',
#  'strange',
#  'sheet',
#  'updates',
#  'pointer',
#  'brings',
#  'trunk',
#  'Status',
#  'setup',
#  'extra',
#  'Load',
#  'SSL',
#  'Does',
#  'remains',
#  'want',
#  'Links',
#  'spaces',
#  'quit',
#  'turn',
#  'Clear',
#  'word',
#  'wont',
#  'hand',
#  'Select',
#  'Empty',
#  'FTP',
#  'seconds',
#  'visited',
#  'Printing',
#  'reset',
#  'Netscape',
#  'element',
#  'xml',
#  'result',
#  'started',
#  'branch',
#  'Button',
#  'mac',
#  'updating',
#  'separator',
#  'manage',
#  'high',
#  'Quick',
#  'implement',
#  'would',
#  'refuses',
#  'customizing',
#  'give',
#  'group',
#  'configuration',
#  'editing',
#  'moving',
#  'Support',
#  'Drag',
#  'because',
#  'mailto',
#  'pressed',
#  'own',
#  'disappeared',
#  'internet',
#  'border',
#  'editor',
#  'client',
#  'general',
#  'resizing',
#  'also',
#  'unless',
#  'There',
#  'stays',
#  'based',
#  'alternate',
#  'become',
#  'read',
#  'finished',
#  'alt',
#  'named',
#  'components',
#  'Parsing',
#  'play',
#  'instance',
#  'choosing',
#  'remembered',
#  'behind',
#  'Saved',
#  'animated',
#  'secondary',
#  'attempt',
#  'engines',
#  'XUL',
#  '#',
#  'patch',
#  'progress',
#  'JS',
#  'hover',
#  'colors',
#  'building',
#  'General',
#  'how',
#  'removing',
#  'F',
#  ...]

# %%
#Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])

# %%
large_words
# Out:
# {'Cookie': 22,
#  'Manager': 179,
#  'allow': 53,
#  'sites': 63,
#  'that': 145,
#  'removed': 21,
#  'cookies': 57,
#  'future': 4,
#  'should': 461,
#  'stay': 21,
#  'checked': 22,
#  'When': 132,
#  'full': 38,
#  'screen': 101,
#  'mode': 51,
#  'Pressing': 9,
#  'Ctrl': 96,
#  'open': 479,
#  'browser': 392,
#  'when': 1255,
#  'only': 139,
#  'download': 297,
#  'dialog': 330,
#  'left': 75,
#  'icons': 106,
#  'context': 104,
#  'menu': 462,
#  'called': 16,
#  'made': 16,
#  'proper': 6,
#  'toolbar': 364,
#  'given': 15,
#  'ability': 25,
#  'collapse': 15,
#  'expand': 29,
#  'Implement': 25,
#  'Cocoa': 1,
#  'style': 40,
#  'customization': 16,
#  'ifdefs': 3,
#  'MOZ_PHOENIX': 4,
#  'customize': 39,
#  'small': 45,
#  'nightly': 28,
#  'builds': 45,
#  'tinderboxen': 1,
#  'Phoenix': 186,
#  'finish': 7,
#  'tearing': 1,
#  'prefs': 33,
#  'pieces': 1,
#  'then': 40,
#  'make': 47,
#  'suck': 3,
#  'mozbrowser': 2,
#  'script': 21,
#  'doesn': 453,
#  'start': 124,
#  'correct': 17,
#  'binary': 8,
#  'Need': 47,
#  'bookmark': 329,
#  'groups': 11,
#  'icon': 180,
#  'Dropping': 2,
#  'palette': 4,
#  'horks': 3,
#  'things': 6,
#  'keyboard': 65,
#  'shortcut': 60,
#  'Increase': 1,
#  'Text': 48,
#  'Size': 10,
#  'broken': 109,
#  'default': 217,
#  'phoenix': 82,
#  'bookmarks': 352,
#  'cust': 24,
#  'need': 31,
#  'spacer': 2,
#  'spring': 1,
#  'launch': 49,
#  'while': 135,
#  'Mozilla': 220,
#  'running': 55,
#  'vice': 3,
#  'versa': 2,
#  'separator': 14,
#  'available': 35,
#  'items': 60,
#  'layout': 11,
#  'history': 119,
#  'back': 121,
#  'buttons': 120,
#  'work': 414,
#  'attempting': 21,
#  'button': 363,
#  'second': 39,
#  'window': 607,
#  'generates': 7,
#  'another': 49,
#  'cannot': 127,
#  'comfortably': 1,
#  'share': 6,
#  'source': 59,
#  'tree': 21,
#  'forgets': 12,
#  'even': 66,
#  'though': 15,
#  'Enable': 17,
#  'current': 58,
#  'session': 29,
#  'chosen': 8,
#  'Starting': 6,
#  'Customizing': 8,
#  'Toolbar': 154,
#  'makes': 34,
#  'page': 719,
#  'blank': 68,
#  'Check': 5,
#  'Satchel': 4,
#  'successor': 1,
#  'wallet': 3,
#  'Mousing': 2,
#  'over': 79,
#  'Personal': 20,
#  'needs': 49,
#  'height': 11,
#  'avoid': 3,
#  'popping': 1,
#  'Folder': 51,
#  'ptoolbar': 1,
#  'Firebird': 437,
#  'Help': 48,
#  'tabs': 246,
#  'close': 157,
#  'wrong': 116,
#  'order': 25,
#  'right': 148,
#  'options': 94,
#  'always': 76,
#  'disabled': 55,
#  'Customising': 1,
#  'breaks': 43,
#  'throbber': 16,
#  'manage': 14,
#  'causes': 161,
#  'hang': 31,
#  'land': 1,
#  'patch': 13,
#  'from': 506,
#  '160019': 1,
#  'Preferences': 64,
#  'Privacy': 21,
#  'Images': 29,
#  'Wonky': 1,
#  'Extremely': 1,
#  'high': 14,
#  'memory': 22,
#  'consumption': 2,
#  'after': 444,
#  'closing': 58,
#  'windows': 195,
#  'with': 680,
#  'Quick': 14,
#  'Launch': 11,
#  'Turbo': 2,
#  'enabled': 46,
#  'have': 134,
#  'implement': 14,
#  'progress': 13,
#  'meter': 2,
#  'URLbar': 2,
#  'view': 78,
#  'tries': 17,
#  'type': 88,
#  'application': 71,
#  'opens': 106,
#  'mozilla': 94,
#  'branding': 2,
#  'auto': 40,
#  'manager': 229,
#  'would': 14,
#  'nice': 7,
#  'Components': 3,
#  'Navigation': 16,
#  'appear': 74,
#  'Modern': 6,
#  'theme': 145,
#  'blocking': 32,
#  'Uabar': 1,
#  'Theme': 34,
#  'changes': 42,
#  'will': 112,
#  'take': 17,
#  'effect': 21,
#  'restart': 37,
#  '_Mozilla_': 1,
#  'large': 39,
#  'Options': 127,
#  'images': 95,
#  'used': 48,
#  'disable': 48,
#  'display': 148,
#  'jumps': 4,
#  'unexpectedly': 4,
#  'bottom': 19,
#  'first': 90,
#  'visible': 33,
#  'Move': 12,
#  'transactions': 1,
#  'into': 104,
#  'service': 5,
#  'adding': 24,
#  'leaks': 4,
#  'Bookmark': 152,
#  'Shortcut': 9,
#  'redo': 1,
#  'does': 594,
#  'Bookmarks': 245,
#  'Eradicate': 1,
#  'AddBookmarkImmediately': 1,
#  'Deleting': 6,
#  'selection': 41,
#  'select': 62,
#  'next': 27,
#  'item': 75,
#  'transaction': 3,
#  'handle': 11,
#  'import': 40,
#  'clears': 5,
#  'increase': 9,
#  'landing': 2,
#  'folder': 193,
#  'single': 21,
#  'click': 253,
#  'twistie': 1,
#  'Pref': 6,
#  'specify': 9,
#  'proxy': 64,
#  'server': 41,
#  'navigation': 30,
#  'improved': 3,
#  'global': 9,
#  'Readd': 1,
#  'Open': 97,
#  'Location': 43,
#  'loading': 119,
#  'Firefox': 602,
#  'ignored': 25,
#  'nsIWindowMediator': 2,
#  'preferences': 102,
#  'longer': 55,
#  'works': 54,
#  'search': 195,
#  'smaller': 6,
#  'Port': 3,
#  '164006': 2,
#  'wyciwyg': 4,
#  'titles': 7,
#  'more': 51,
#  'textmode': 1,
#  'hover': 13,
#  'state': 21,
#  'enable': 23,
#  'nsITheme': 1,
#  'form': 118,
#  'control': 21,
#  'goodness': 1,
#  'rename': 11,
#  'executable': 7,
#  'profile': 95,
#  'password': 124,
#  'Extension': 48,
#  'confusing': 3,
#  'much': 11,
#  'Missing': 15,
#  'image': 134,
#  'Cannot': 81,
#  'File': 67,
#  'managing': 4,
#  'loaded': 42,
#  'switched': 4,
#  'Pretty': 1,
#  'error': 214,
#  'middle': 67,
#  'loads': 41,
#  'Nightly': 3,
#  'Sept': 1,
#  'displays': 54,
#  'details': 7,
#  'above': 22,
#  'listboxes': 3,
#  'views': 1,
#  'support': 55,
#  'themes': 70,
#  'winxp': 2,
#  'Mousewheel': 5,
#  'resize': 22,
#  'text': 279,
#  'Please': 17,
#  'tell': 5,
#  'people': 1,
#  'combine': 2,
#  'links': 134,
#  'Import': 15,
#  'About': 49,
#  'weirdness': 4,
#  'Context': 27,
#  'clicking': 198,
#  'forward': 27,
#  'cookie': 36,
#  'Proxy': 9,
#  'settings': 47,
#  'seem': 12,
#  'Incorrectly': 2,
#  'renders': 17,
#  'various': 7,
#  'pages': 142,
#  'Window': 40,
#  'show': 114,
#  'completely': 29,
#  'change': 91,
#  'privacy': 9,
#  'Imported': 4,
#  'Favorites': 3,
#  'personal': 29,
#  'pheonix': 4,
#  'Blank': 7,
#  'using': 222,
#  'Customize': 35,
#  'scroll': 129,
#  'ctrl': 49,
#  'switch': 31,
#  'favicon': 32,
#  'colors': 13,
#  'render': 28,
#  'improperly': 4,
#  'remote': 24,
#  'openurl': 2,
#  'resizable': 12,
#  'Scroll': 20,
#  'becomes': 15,
#  'addressbar': 7,
#  'dropdown': 55,
#  'linux': 28,
#  'Find': 93,
#  'Next': 10,
#  'respond': 20,
#  'Enter': 26,
#  'cycle': 3,
#  'Copy': 12,
#  'load': 128,
#  'same': 69,
#  'width': 19,
#  'table': 24,
#  'containing': 20,
#  'being': 49,
#  'handled': 10,
#  'incorrectly': 40,
#  'multiple': 83,
#  'screenwidths': 1,
#  'wide': 7,
#  'accessing': 24,
#  'navigator': 11,
#  'cookieEnabled': 2,
#  'produces': 10,
#  'uncaught': 3,
#  'exception': 21,
#  'newsgroup': 2,
#  'Revive': 1,
#  'preprocessor': 8,
#  'talkback': 2,
#  'refuses': 14,
#  'missing': 102,
#  'libstdc': 4,
#  'libc6': 1,
#  'restore': 16,
#  'dragging': 24,
#  'empty': 56,
#  'area': 25,
#  'fullscreen': 21,
#  'minimize': 9,
#  'arrows': 15,
#  'magically': 1,
#  'move': 30,
#  'paste': 19,
#  'Windows': 109,
#  'imported': 22,
#  'favorites': 11,
#  'every': 30,
#  'resolve': 5,
#  'September': 1,
#  'Cache': 8,
#  'appears': 79,
#  'twice': 25,
#  'onload': 4,
#  'Ability': 24,
#  'tabgroups': 1,
#  'homepages': 5,
#  'wordwrap': 2,
#  'news': 8,
#  'article': 2,
#  'resume': 3,
#  'choice': 11,
#  'mouse': 114,
#  'position': 25,
#  'insetad': 1,
#  'unexplained': 1,
#  'crash': 258,
#  'disappear': 32,
#  'installation': 44,
#  'appearance': 2,
#  'urlbar': 15,
#  'Linux': 47,
#  'Changes': 4,
#  'building': 13,
#  'Clicking': 63,
#  'targeted': 2,
#  'link': 244,
#  'address': 127,
#  'everything': 5,
#  'possible': 27,
#  'build': 114,
#  'size': 91,
#  'features': 10,
#  'fixup': 4,
#  'dropping': 3,
#  'communicator': 3,
#  'showing': 31,
#  'tool': 10,
#  'stops': 36,
#  'focuses': 3,
#  'Version': 8,
#  'number': 22,
#  'sorting': 9,
#  'been': 26,
#  'long': 26,
#  'Trying': 4,
#  'submit': 34,
#  '171196': 1,
#  'generated': 10,
#  'color': 29,
#  'strange': 15,
#  'represent': 1,
#  'labels': 5,
#  'field': 97,
#  'fields': 34,
#  'cancel': 23,
#  'buggy': 3,
#  'Browser': 92,
#  'ignoring': 3,
#  'attibute': 1,
#  'TITLE': 9,
#  'Back': 31,
#  'skips': 1,
#  'wrap': 8,
#  'Created': 2,
#  'what': 19,
#  'think': 2,
#  'able': 23,
#  'URLbars': 1,
#  'customizing': 14,
#  'toolbars': 32,
#  'Creating': 5,
#  'name': 77,
#  'standard': 16,
#  'give': 14,
#  'menubutton': 1,
#  'General': 13,
#  'redesign': 2,
#  'expose': 6,
#  'launching': 20,
#  'userfriendly': 1,
#  'shows': 80,
#  'reload': 28,
#  'stop': 38,
#  'removing': 13,
#  'deletes': 11,
#  'hidden': 23,
#  'part': 27,
#  'inplace': 1,
#  'popup': 109,
#  'whitelisting': 6,
#  'file': 315,
#  'export': 10,
#  'characters': 42,
#  'autocomplete': 103,
#  'Edit': 18,
#  'Freeze': 5,
#  'sized': 6,
#  'larger': 8,
#  'fonts': 29,
#  'sheet': 15,
#  'comes': 7,
#  'place': 20,
#  'satchel': 2,
#  'allows': 8,
#  'tabbing': 9,
#  'presented': 4,
#  'content': 62,
#  'files': 163,
#  'without': 65,
#  'flag': 4,
#  'scripts': 8,
#  'instead': 118,
#  'mapped': 4,
#  'Needs': 7,
#  'space': 30,
#  'between': 41,
#  'toolbarbuttons': 1,
#  'creates': 21,
#  'directory': 72,
#  'Background': 9,
#  'transparent': 9,
#  'fails': 162,
#  'Dropmarker': 1,
#  'depress': 1,
#  'luna': 1,
#  'Autocomplete': 35,
#  'Homepage': 3,
#  'pref': 38,
#  'Focus': 11,
#  'going': 20,
#  'http': 112,
#  'offline': 5,
#  'sidebar': 114,
#  'overflow': 20,
#  'deletion': 4,
#  'individual': 7,
#  'results': 36,
#  'dropmarker': 4,
#  'enter': 51,
#  'selected': 82,
#  'View': 68,
#  'Sidebars': 5,
#  'Crash': 130,
#  'additions': 2,
#  'Microsoft': 8,
#  'Outlook': 12,
#  'posting': 1,
#  'reply': 6,
#  'group': 14,
#  'Download': 144,
#  'finishes': 9,
#  'prematurely': 2,
#  'Unable': 49,
#  'create': 34,
#  'selecting': 38,
#  'BOOKMARK': 1,
#  'Quits': 1,
#  'Attempting': 5,
#  'Access': 13,
#  'MyCheckFree': 1,
#  'Will': 8,
#  'Creative': 1,
#  'drivers': 3,
#  'tweaking': 1,
#  'Doesn': 9,
#  'forces': 6,
#  'exceeds': 1,
#  'Cust': 1,
#  'Closing': 12,
#  'customisation': 2,
#  'Done': 7,
#  'Typeahead': 2,
#  'find': 58,
#  'delete': 39,
#  'Delete': 11,
#  'searchplugins': 4,
#  'Separators': 1,
#  'Misplaced': 1,
#  'Sidebar': 39,
#  'Tools': 65,
#  'History': 56,
#  'folders': 66,
#  'POPUP': 2,
#  'panel': 23,
#  'prperly': 1,
#  'version': 70,
#  'info': 33,
#  'lists': 10,
#  'crashes': 291,
#  'MAILTO': 1,
#  'supported': 10,
#  'groupmark': 1,
#  'gives': 33,
#  'connection': 38,
#  'failure': 22,
#  'menubar': 11,
#  'inactive': 10,
#  'separate': 9,
#  'configuration': 14,
#  'Search': 62,
#  'distinct': 2,
#  'each': 31,
#  'menus': 73,
#  'including': 7,
#  'remove': 56,
#  'Exit': 5,
#  'replace': 8,
#  'Close': 23,
#  'Remove': 35,
#  'user': 88,
#  'added': 27,
#  'option': 130,
#  'POSTDATA': 5,
#  'confirm': 8,
#  'your': 12,
#  'black': 20,
#  'stories': 1,
#  'correctly': 77,
#  'Make': 35,
#  'Export': 2,
#  'specific': 23,
#  'managed': 1,
#  'Selecting': 20,
#  'grouped': 1,
#  'saved': 64,
#  'replicates': 1,
#  'Keyboard': 16,
#  'editing': 14,
#  'forms': 29,
#  'useragent': 6,
#  'messes': 4,
#  'Yahoo': 28,
#  'compose': 4,
#  'checking': 6,
#  'moving': 14,
#  'splitter': 1,
#  'problems': 38,
#  'Slow': 7,
#  'focus': 113,
#  'textboxes': 4,
#  'resizer': 3,
#  'maximized': 11,
#  'Cancelling': 1,
#  'creation': 3,
#  'still': 46,
#  'leaves': 13,
#  'JavaScript': 53,
#  'hitting': 9,
#  'Cancel': 19,
#  'Choosing': 9,
#  'Expand': 5,
#  'Opens': 5,
#  'incorrect': 37,
#  'tooltip': 22,
#  'Encryption': 3,
#  'security': 16,
#  'warnings': 6,
#  'alert': 33,
#  'whenever': 10,
#  'schedule': 3,
#  'some': 109,
#  'sort': 17,
#  'cros': 1,
#  'betwean': 1,
#  'properly': 80,
#  'minor': 3,
#  'down': 147,
#  'arrow': 36,
#  'list': 91,
#  'flex': 1,
#  'textbox': 27,
#  'Custom': 6,
#  'opening': 156,
#  'javascript': 91,
#  'activate': 3,
#  'Maybe': 1,
#  'gestures': 6,
#  'compatable': 1,
#  'foreign': 2,
#  'Paste': 8,
#  'HTTP': 23,
#  'Support': 14,
#  'Server': 8,
#  'persist': 6,
#  'across': 8,
#  'sessions': 6,
#  'trying': 87,
#  'browse': 10,
#  'failed': 23,
#  'locked': 7,
#  'placing': 2,
#  'Print': 49,
#  'Preview': 25,
#  'busted': 3,
#  'case': 11,
#  'insensitive': 1,
#  'menuitems': 1,
#  'tooltips': 8,
#  'croppeed': 1,
#  'Windowblinds': 2,
#  'reorder': 3,
#  'jprof': 1,
#  'Javascript': 58,
#  'side': 20,
#  'Save': 83,
#  'Page': 163,
#  'shuld': 2,
#  'offer': 8,
#  'Caption': 1,
#  'Drag': 14,
#  'Menu': 65,
#  'main': 45,
#  'chrome': 45,
#  'networking': 2,
#  'core': 4,
#  'tests': 1,
#  'deskmod': 1,
#  'mozdev': 2,
#  'apply': 9,
#  'keyword': 20,
#  'displayed': 84,
#  'Internet': 39,
#  'Keywords': 11,
#  'Mozgesture': 1,
#  'extension': 122,
#  'prevents': 13,
#  'authentication': 18,
#  'charset': 4,
#  'autodetector': 1,
#  'working': 96,
#  'modern': 3,
#  'listing': 5,
#  'package': 5,
#  'accel': 4,
#  'shift': 21,
#  'keystroke': 2,
#  'nothing': 38,
#  'updates': 15,
#  'vbox': 2,
#  'appcontent': 1,
#  'hook': 2,
#  'pointer': 15,
#  'Customization': 7,
#  'preference': 36,
#  'hide': 16,
#  'occurs': 10,
#  'ONLY': 2,
#  'management': 9,
#  'Sorts': 1,
#  'reflected': 2,
#  'drop': 106,
#  'Under': 5,
#  'pulldown': 3,
#  'problem': 48,
#  'checker': 4,
#  'this': 175,
#  'prefernces': 2,
#  'disappears': 25,
#  'drag': 51,
#  'release': 28,
#  'Character': 3,
#  'Coding': 2,
#  'reflect': 5,
#  'character': 36,
#  'coding': 4,
#  'trouble': 2,
#  'command': 40,
#  'Popup': 39,
#  'MOZILLA_FIVE_HOME': 1,
#  'Java': 46,
#  'starting': 34,
#  'phantom': 2,
#  'invalid': 16,
#  'URLs': 42,
#  'Downloads': 36,
#  'quickly': 9,
#  'typing': 24,
#  'gkcontent': 1,
#  'percentage': 10,
#  'differs': 4,
#  'real': 7,
#  'because': 14,
#  'Multiple': 13,
#  'instances': 13,
#  'responding': 21,
#  'opened': 91,
#  'manually': 13,
#  'prepending': 1,
#  'Current': 9,
#  'downloads': 52,
#  'updated': 29,
#  'path': 21,
#  'where': 29,
#  'downloaded': 30,
#  'contains': 30,
#  'accent': 3,
#  'Allow': 19,
#  'external': 31,
#  'viewer': 9,
#  'Home': 31,
#  'about': 114,
#  'useless': 5,
#  'pause': 9,
#  'java': 39,
#  'plugin': 57,
#  'look': 16,
#  'plugins': 26,
#  'home': 62,
#  'Rename': 10,
#  'Login': 9,
#  'forum': 8,
#  'unsuccessful': 1,
#  'other': 95,
#  'applications': 17,
#  'reuse': 3,
#  'regression': 6,
#  'chevron': 6,
#  'changing': 39,
#  'contents': 22,
#  'clear': 35,
#  'onLoad': 2,
#  'Pageload': 1,
#  'startup': 92,
#  'spiked': 1,
#  'landed': 1,
#  'visual': 10,
#  'indication': 10,
#  'they': 12,
#  'deleted': 28,
#  'External': 4,
#  'Mail': 18,
#  'Program': 11,
#  'With': 17,
#  'cache': 37,
#  'Middle': 30,
#  'copied': 3,
#  'Block': 11,
#  'favour': 1,
#  'Exception': 5,
#  'specifying': 1,
#  'anything': 19,
#  'Functionality': 1,
#  'servers': 10,
#  'format': 8,
#  'animations': 5,
#  'embeded': 2,
#  'profilename': 1,
#  'brings': 15,
#  'wizard': 9,
#  'test': 8,
#  'infrastructure': 1,
#  'trunk': 15,
#  'mailto': 14,
#  'handler': 10,
#  'third': 7,
#  'party': 3,
#  'email': 23,
#  'clients': 1,
#  'doesnt': 32,
#  'shut': 4,
#  'closed': 46,
#  'fatal': 3,
#  'Favicon': 6,
#  'iframe': 11,
#  'refresh': 31,
#  'typeahead': 2,
#  'visibility': 2,
#  'times': 35,
#  'flash': 43,
#  'games': 5,
#  'simultaneously': 4,
#  'Display': 19,
#  'Favicons': 10,
#  'location': 132,
#  'print': 97,
#  'preview': 59,
#  'Dragging': 12,
#  'pressed': 14,
#  'puts': 6,
#  'gone': 9,
#  'prefable': 1,
#  'append': 4,
#  'Wrong': 43,
#  'information': 41,
#  'infinitely': 3,
#  'increasing': 5,
#  'correction': 3,
#  'entry': 39,
#  'duplicated': 6,
#  'upon': 32,
#  'viewing': 32,
#  'clash': 1,
#  'additional': 3,
#  'network': 24,
#  'cookieBehavior': 1,
#  'automatically': 32,
#  'Status': 15,
#  'Tidyness': 1,
#  'checkmark': 2,
#  'present': 21,
#  'horked': 2,
#  'customized': 4,
#  'string': 31,
#  'Name': 7,
#  'Keyword': 4,
#  'Regression': 4,
#  'occasion': 1,
#  'double': 30,
#  'focused': 10,
#  'appl': 1,
#  'contrast': 4,
#  'distinguish': 2,
#  'active': 30,
#  'Cookies': 17,
#  'Preference': 6,
#  'originating': 10,
#  'settable': 2,
#  'aren': 13,
#  'browsing': 44,
#  'First': 10,
#  'time': 81,
#  'issue': 7,
#  'different': 39,
#  'objects': 7,
#  'Tabs': 45,
#  'loses': 20,
#  'forgotten': 6,
#  'shutdown': 9,
#  'xpinstall': 3,
#  'Running': 8,
#  'firefox': 236,
#  'xfeDoCommand': 2,
#  'openInbox': 1,
#  'Gives': 2,
#  'Error': 78,
#  'viewable': 2,
#  'return': 12,
#  'existing': 25,
#  'keep': 9,
#  'painting': 4,
#  'Full': 22,
#  'Editing': 3,
#  'inline': 9,
#  'under': 60,
#  'inaccurate': 2,
#  'impossible': 7,
#  'copy': 35,
#  'Small': 5,
#  'Icons': 18,
#  'value': 29,
#  'Source': 35,
#  'modal': 9,
#  'Icon': 22,
#  'kind': 3,
#  'gots': 1,
#  'visit': 13,
#  'marker': 1,
#  'collapsing': 1,
#  'Send': 12,
#  'Link': 42,
#  'behavior': 20,
#  'reusage': 1,
#  'disappeared': 14,
#  'choose': 26,
#  'last': 52,
#  'screwed': 3,
#  'Regular': 1,
#  'suffering': 1,
#  'internet': 14,
#  'occur': 4,
#  'ntdll': 3,
#  'Speed': 2,
#  'feature': 27,
#  'Configuration': 3,
#  'manual': 5,
#  'tabbrowser': 3,
#  'Plugin': 17,
#  'Downloader': 2,
#  'reported': 6,
#  'Poor': 2,
#  'Clean': 8,
#  'menuitem': 3,
#  'defaults': 16,
#  'homepage': 37,
#  'action': 24,
#  'appearing': 8,
#  'encoding': 13,
#  'WinXP': 11,
#  'Stop': 10,
#  'getting': 9,
#  'services': 1,
#  'site': 170,
#  'functionality': 22,
#  'clearing': 9,
#  'Notify': 2,
#  'favicons': 17,
#  'topbar': 1,
#  'errors': 11,
#  'Option': 30,
#  'most': 12,
#  'shortcuts': 26,
#  'URIbar': 1,
#  'Specific': 2,
#  'Google': 21,
#  'freezes': 50,
#  'replaces': 2,
#  ...}

# %%
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50, cumulative= False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %%
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %%
#Build a word cloud
from wordcloud import WordCloud

# %%
wcloud = WordCloud().generate_from_frequencies(frequency_dist)

# %%
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
